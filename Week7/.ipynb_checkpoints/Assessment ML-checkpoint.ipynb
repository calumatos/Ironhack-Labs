# %%
from os import times
import pandas as pd
from io import StringIO

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

import numpy as np

# %%
data = pd.read_csv('target.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 data = pd.read_csv('target.csv')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'target.csv'

# %%
def split_dataset(titanic_csv):
    """
    Split the Titanic dataset into training and test sets.

    Parameters:
        titanic_csv (str): The path to the Titanic dataset in CSV format.

    Returns:
        X_train (pandas.DataFrame): The feature data for the training set.
        X_test (pandas.DataFrame): The feature data for the test set.
        y_train (pandas.Series): The target data for the training set.
        y_test (pandas.Series): The target data for the test set.
    
    """
    pass

def clean_missing_values(X_train, X_test, column_names=["Age","Embarked"], drop_columns=["Cabin"]):
    """
    Clean missing values in specified columns in train and test dataframes and drop specified columns.
    
    Args:
    train_df (pandas.DataFrame): The training dataset.
    test_df (pandas.DataFrame): The test dataset.
    column_names (list): The names of columns to clean missing values.
    drop_columns (list): The names of columns to drop.
    
    Returns:
    train_df (pandas.DataFrame): The cleaned training dataset.
    test_df (pandas.DataFrame): The cleaned test dataset.
    """
    
    pass

def feature_engineering(X_train, X_test, label_encoders = {'Sex':"LabelEncoder", 'Embarked':"OneHotEncoder"}, drop_cols=['SibSp', 'Parch', 'Sex', 'Embarked', 'PassengerId', 'Name', 'Ticket']):
    """
    Performs feature engineering (feature encoding, creating a new column -TravelAlone-, and dropping columns) on the cleaned Titanic dataset.

    Parameters:
    -----------
    X_train : pandas.DataFrame
        The cleaned training set containing the Titanic dataset.
    X_test : pandas.DataFrame
        The cleaned test set containing the Titanic dataset.
    label_encoders : dict, optional (default={'Sex': "LabelEncoder", 'Embarked': "OneHotEncoder"})
        A dictionary specifying the label encoders to use for each categorical column.
        The keys are the column names and the values are the string names of the encoders to use.
        Currently, the function supports "LabelEncoder" and "OneHotEncoder".
    drop_cols : list, optional (default=['SibSp', 'Parch', 'Sex', 'Embarked', 'PassengerId', 'Name', 'Ticket'])
        A list of columns to drop from the dataset after feature engineering.

    Returns:
    --------
    X_train : pandas.DataFrame
        The training set with feature engineering applied.
    X_test : pandas.DataFrame
        The test set with feature engineering applied.
    """
    pass

def feature_scaling(X_train,X_test):
    """
    Applies feature scaling on the input data using StandardScaler from scikit-learn.

    Parameters:
    X_train (pandas.DataFrame): Training data to scale, with feature engineering already done to it.
    X_test (pandas.DataFrame): Test data to scale, with feature engineering already done to it.

    Returns:
    X_train_transf (numpy.ndarray): Scaled training data.
    X_test_transf (numpy.ndarray): Scaled test data.
    """
    scaler = StandardScaler()
    st_scale = StandardScaler()
    X_train_transf = st_scale.fit_transform(X_train)
    X_test_transf = st_scale.transform(X_test)
    return X_train_transf, X_test_transf
    
def log_reg_pred(X_train_transf, X_test_transf, y_train, y_test):
    """
    Train and evaluate a logistic regression classifier.

    Parameters:
    X_train_transf (array-like): Scaled training data.
    X_test_transf (array-like): Scaled test data.
    y_train (array-like): Labels for training data.
    y_test (array-like): Labels for test data.

    Returns:
    float: Accuracy score of the logistic regression classifier on the test data.
    """
    pass
  
def rf_pred(X_train,X_test, y_train, y_test):
    """
    Train and evaluate a random forest classifier.

    Parameters:
    X_train (array-like): Training data after feature engineering (data is not scaled).
    X_test (array-like): Test data after feature engineering (data is not scaled)
    y_train (array-like): Labels for training data.
    y_test (array-like): Labels for test data.

    Returns:
    float: Accuracy score of the random forest classifier on the test data.
    """
    pass

def feature_selection_rf(X_train, X_test, y_train, y_test):
    """
    Perform feature selection using Random Forest Classifier.

    Parameters:
    X_train (numpy.ndarray): Array of training data features after feature engineering (data is not scaled).
    X_test (numpy.ndarray): Array of test data features after feature engineering (data is not scaled).
    y_train (array-like): Labels for training data.
    y_test (array-like): Labels for test data.

    Returns:
    list: List containing 5 feature names which got the top 5 importance scores, in descending order
    """
    pass

def hyperparam_tuning_rf(X_train,X_test, y_train, y_test):
    """
    Tune hyperparameters for a Random Forest Classifier using grid search with cross-validation.
    
    Parameters:
    X_train (numpy.ndarray): Array of training data features after feature engineering (data is not scaled).
    X_test (numpy.ndarray): Array of test data features after feature engineering (data is not scaled).
    y_train (numpy.ndarray): Array of training data labels.
    y_test (numpy.ndarray): Array of test data labels.
    
    Returns:
    tuple : (float, float) Returns a tuple containing the accuracy score of the best estimator on the training set and the accuracy score 
        of the predicted values on the testing set.
    """
    pass
